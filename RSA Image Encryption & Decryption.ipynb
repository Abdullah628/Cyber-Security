# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/content/sample_data/cat.jpeg')
my_img = cv2.resize(img, (204, 233))
cv2_imshow(my_img)
# Out:
# <PIL.Image.Image image mode=RGB size=204x233>

# %%
#RSA
from random import randrange, getrandbits
#calculates modular exponentiation
def power(a,d,n):
  ans=1;
  while d!=0:
    if d%2==1:
      ans=((ans%n)*(a%n))%n
    a=((a%n)*(a%n))%n
    d>>=1
  return ans;
#check if a number N is probably prime.
def MillerRabin(N,d):
  a = randrange(2, N - 1)
  x=power(a,d,N);
  if x==1 or x==N-1:
    return True;
  else:
    while(d!=N-1):
      x=((x%N)*(x%N))%N;
      if x==1:
        return False;
      if x==N-1:
        return True;
      d<<=1;
  return False;
#checks if a number N is prime using the Miller-Rabin test with K iterations
def is_prime(N,K):
  if N==3 or N==2:
    return True;
  if N<=1 or N%2==0:
    return False;

  d=N-1
  while d%2!=0:
    d/=2;

  for _ in range(K):
    if not MillerRabin(N,d):
      return False;
  return True;

def generate_prime_candidate(length):
  # generate random bits
  p = getrandbits(length)
  #Set LSB to 1 to make sure we get a Odd Number.
  p |= (1 << length - 1) | 1
  return p

def generatePrimeNumber(length):
  A=4
  while not is_prime(A, 128):
        A = generate_prime_candidate(length)
  return A

length=5
P=generatePrimeNumber(length)
Q=generatePrimeNumber(length)

print(P)
print(Q)
# Out:
# 19
# 23

# %%
#Euler Totient Function = (P-1)*(Q-1)
N=P*Q
eulerTotient=(P-1)*(Q-1)
print(N)
print(eulerTotient)
# Out:
# 437
# 396

# %%
def GCD(a,b):
  if a==0:
    return b;
  return GCD(b%a,a)

E=generatePrimeNumber(4)
while GCD(E,eulerTotient)!=1:
  E=generatePrimeNumber(4)
print(E)
# Out:
# 13

# %%
def gcdExtended(E,eulerTotient):
  a1,a2,b1,b2,d1,d2=1,0,0,1,eulerTotient,E
  while d2!=1:
    #k
    k=(d1//d2)
    #a
    temp=a2
    a2=a1-(a2*k)
    a1=temp
    #b
    temp=b2
    b2=b1-(b2*k)
    b1=temp
    #d
    temp=d2
    d2=d1-(d2*k)
    d1=temp
    D=b2
  if D>eulerTotient:
    D=D%eulerTotient
  elif D<0:
    D=D+eulerTotient
  return D

D=gcdExtended(E,eulerTotient)
print(D)
# Out:
# 61

# %%
my_img = plt.imread('/content/sample_data/cat.jpeg')

row,col = my_img.shape[0],my_img.shape[1]
enc = [[0 for x in range(3000)] for y in range(3000)]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Step 5: Encryption
my_img = my_img.copy()
my_img.flags.writeable = True
for i in range(0, 233):
  for j in range(0, 204):
    r,g,b=my_img[i,j]
    C1=power(r,E,N)
    C2=power(g,E,N)
    C3=power(b,E,N)
    enc[i][j]=[C1,C2,C3]
    C1=C1%256
    C2=C2%256
    C3=C3%256
    my_img[i, j] = (C1, C2, C3)

cv2_imshow(my_img)
# Out:
# <PIL.Image.Image image mode=RGB size=204x233>

# %%
#Step 6: Decryption

for i in range(0,233):
  for j in range(0,204):
    r,g,b=enc[i][j]
    M1=power(r,D,N)
    M2=power(g,D,N)
    M3=power(b,D,N)
    my_img[i,j]=[M1,M2,M3]

cv2_imshow(my_img)
# Out:
# <PIL.Image.Image image mode=RGB size=204x233>
